# %% [markdown]
# ## Pandas-Data Filtering

# %%
import pandas as pd
import numpy as np

# %%
movies_df = pd.read_csv('movies_data.csv')
movies_df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies_df.loc[movies_df['genre']=='Crime']
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
movies_df[movies_df['genre']=='Crime']
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
movies_df[movies_df['genre']=='Action']
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
movies_df['genre'].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
movies_df[(movies_df['genre']=='Horror')  | 
          (movies_df['genre']=='Sci-Fi')  |
         (movies_df['genre']== 'Adventure')].shape
# Out:
# (109, 6)

# %%
movies_df.loc[(movies_df['genre']=='Horror')  | 
          (movies_df['genre']=='Sci-Fi')  |
         (movies_df['genre']== 'Adventure')]
# Out:
#      star_rating                                              title  \
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 14           8.8              The Lord of the Rings: The Two Towers
# 15           8.7                                       Interstellar
# 39           8.6                                             Psycho
# ..           ...                                                ...
# 937          7.4                                          Labyrinth
# 943          7.4                                    The Bucket List
# 953          7.4                              The NeverEnding Story
# 975          7.4                        Back to the Future Part III
# 977          7.4                                        Poltergeist
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 10           PG-13  Adventure       178
# ...

# %%
movies_df[(movies_df['genre']=='Horror') |
         (movies_df['content_rating']=='PG-13')]
# Out:
#      star_rating                                              title  \
# 3            9.0                                    The Dark Knight
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 13           8.8                                       Forrest Gump
# ..           ...                                                ...
# 965          7.4                                          Limitless
# 966          7.4                                 The Simpsons Movie
# 973          7.4                              The Cider House Rules
# 976          7.4    Master and Commander: The Far Side of the World
# 977          7.4                                        Poltergeist
#
#     content_rating      genre  duration  \
# 3            PG-13     Action       152
# 7            PG-13  Adventure       201
# ...

# %%
movies_df[(movies_df['genre']=='Horror') |
         (movies_df['content_rating']=='PG-13') |
         (movies_df['duration'] >= 150)]
# Out:
#      star_rating                                            title  \
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 6            8.9                   The Good, the Bad and the Ugly
# ..           ...                                              ...
# 966          7.4                               The Simpsons Movie
# 968          7.4                              The English Patient
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
#
#     content_rating      genre  duration  \
# 1                R      Crime       175
# 2                R      Crime       200
# 3            PG-13     Action       152
# ...

# %%
movies_df[movies_df['genre']=='Comedy']
# Out:
#      star_rating                                              title  \
# 25           8.6                                  Life Is Beautiful
# 29           8.6                                        City Lights
# 35           8.6                                       Modern Times
# 48           8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 52           8.5                                 The Great Dictator
# ..           ...                                                ...
# 959          7.4                               Deconstructing Harry
# 960          7.4                                   The Way Way Back
# 962          7.4                                 Driving Miss Daisy
# 971          7.4                                 Death at a Funeral
# 974          7.4                                            Tootsie
#
#     content_rating   genre  duration  \
# 25           PG-13  Comedy       116
# 29          PASSED  Comedy        87
# ...

# %%
movies_df[(movies_df['genre']=='Comedy') & 
         (movies_df['genre']=='Adventure')]
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, genre, duration, actors_list]
# Index: []

# %%
movies_df[(movies_df['genre']=='Comedy') | 
         (movies_df['genre']=='Adventure')]
# Out:
#      star_rating                                              title  \
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 14           8.8              The Lord of the Rings: The Two Towers
# 15           8.7                                       Interstellar
# 25           8.6                                  Life Is Beautiful
# ..           ...                                                ...
# 960          7.4                                   The Way Way Back
# 962          7.4                                 Driving Miss Daisy
# 971          7.4                                 Death at a Funeral
# 974          7.4                                            Tootsie
# 975          7.4                        Back to the Future Part III
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 10           PG-13  Adventure       178
# ...

# %%
movies_df[(movies_df['genre']=='Comedy') |
         (movies_df['content_rating']=='PG-13')]
# Out:
#      star_rating                                              title  \
# 3            9.0                                    The Dark Knight
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 13           8.8                                       Forrest Gump
# ..           ...                                                ...
# 966          7.4                                 The Simpsons Movie
# 971          7.4                                 Death at a Funeral
# 973          7.4                              The Cider House Rules
# 974          7.4                                            Tootsie
# 976          7.4    Master and Commander: The Far Side of the World
#
#     content_rating      genre  duration  \
# 3            PG-13     Action       152
# 7            PG-13  Adventure       201
# ...

# %%
movies_df[(movies_df['genre']=='Comedy') &
         (movies_df['content_rating']=='PG-13')]
# Out:
#      star_rating                                           title  \
# 25           8.6                               Life Is Beautiful
# 60           8.5                                        3 Idiots
# 314          8.0                         Crimes and Misdemeanors
# 356          8.0                                      The Artist
# 370          8.0                          Hannah and Her Sisters
# 459          7.9                        Ferris Bueller's Day Off
# 542          7.8                            (500) Days of Summer
# 578          7.8                              As Good as It Gets
# 622          7.7                                 The Dinner Game
# 639          7.7                                    Billy Elliot
# 667          7.7                               Midnight in Paris
# 696          7.7                           Stranger Than Fiction
# 735          7.6  The Naked Gun: From the Files of Police Squad!
# ...

# %%
movies_df[(movies_df['genre']=='Western') |
          (movies_df['genre']=='Comedy') &
         (movies_df['content_rating']=='PG-13')]
# Out:
#      star_rating                                           title  \
# 6            8.9                  The Good, the Bad and the Ugly
# 25           8.6                               Life Is Beautiful
# 26           8.6                    Once Upon a Time in the West
# 59           8.5                                Django Unchained
# 60           8.5                                        3 Idiots
# 107          8.3                          For a Few Dollars More
# 119          8.3                                      Unforgiven
# 236          8.1                                       High Noon
# 263          8.1                                       Rio Bravo
# 314          8.0                         Crimes and Misdemeanors
# 356          8.0                                      The Artist
# 370          8.0                          Hannah and Her Sisters
# 421          7.9                          The Outlaw Josey Wales
# ...

# %%
movies_df[((movies_df['genre']=='Western') |
          (movies_df['genre']=='Comedy')) &
         (movies_df['content_rating']=='PG-13')]
# Out:
#      star_rating                                           title  \
# 25           8.6                               Life Is Beautiful
# 26           8.6                    Once Upon a Time in the West
# 60           8.5                                        3 Idiots
# 314          8.0                         Crimes and Misdemeanors
# 356          8.0                                      The Artist
# 370          8.0                          Hannah and Her Sisters
# 459          7.9                        Ferris Bueller's Day Off
# 542          7.8                            (500) Days of Summer
# 578          7.8                              As Good as It Gets
# 622          7.7                                 The Dinner Game
# 639          7.7                                    Billy Elliot
# 667          7.7                               Midnight in Paris
# 696          7.7                           Stranger Than Fiction
# ...

# %%
movies_df[(movies_df['duration']>= 120) &
         (movies_df['duration'] <= 150)]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 9            8.9                                       Fight Club
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                     Forrest Gump
# ..           ...                                              ...
# 964          7.4                                          Lincoln
# 967          7.4                                         The Rock
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 9                R      Drama       139
# 11           PG-13     Action       148
# ...

# %%
movies_df.loc[(movies_df['duration']>= 120) &
         (movies_df['duration'] <= 150)]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 9            8.9                                       Fight Club
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                     Forrest Gump
# ..           ...                                              ...
# 964          7.4                                          Lincoln
# 967          7.4                                         The Rock
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 9                R      Drama       139
# 11           PG-13     Action       148
# ...

# %%
movies_df[movies_df['duration'].between(120,150)]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 9            8.9                                       Fight Club
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                     Forrest Gump
# ..           ...                                              ...
# 964          7.4                                          Lincoln
# 967          7.4                                         The Rock
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 9                R      Drama       139
# 11           PG-13     Action       148
# ...

# %%
movies_df.loc[movies_df['duration'].between(120,150)]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 9            8.9                                       Fight Club
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                     Forrest Gump
# ..           ...                                              ...
# 964          7.4                                          Lincoln
# 967          7.4                                         The Rock
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 9                R      Drama       139
# 11           PG-13     Action       148
# ...

# %%
movies_df['duration'].between(120,150).sum()
# Out:
# 330

# %%
movies_df[(movies_df['genre']=='Action') | (movies_df['genre']=='Family')]['content_rating'].value_counts()
# Out:
# R            67
# PG-13        44
# PG           12
# NOT RATED     4
# UNRATED       3
# APPROVED      3
# G             2
# PASSED        1
# GP            1
# Name: content_rating, dtype: int64

# %%
movies_df[((movies_df['genre']=='Action') | (movies_df['genre']=='Family'))  &
         (movies_df['content_rating']=='R')]
# Out:
#      star_rating                       title content_rating   genre  duration  \
# 20           8.7                  The Matrix              R  Action       136
# 36           8.6         Saving Private Ryan              R  Action       169
# 44           8.5                   Gladiator              R  Action       155
# 45           8.5  Terminator 2: Judgment Day              R  Action       137
# 75           8.4                      Aliens              R  Action       137
# ..           ...                         ...            ...     ...       ...
# 885          7.5                Total Recall              R  Action       113
# 906          7.5                      Looper              R  Action       119
# 918          7.5              Running Scared              R  Action       122
# 963          7.4             La Femme Nikita              R  Action       118
# 967          7.4                    The Rock              R  Action       136
#
# ...

# %%
movies_df[((movies_df['genre']=='Action') | (movies_df['genre']=='Family'))  &
         (movies_df['content_rating']=='R') &
         ((movies_df['duration']>= 120) & (movies_df['duration'] <= 150))].shape
# Out:
# (24, 6)

# %%
movies_df[((movies_df['genre']=='Action') | (movies_df['genre']=='Family'))  &
         (movies_df['content_rating']=='R') &
         (movies_df['duration'].between(120,150))].shape
# Out:
# (24, 6)

# %%
movies_df[((movies_df['genre']=='Action') | (movies_df['genre']=='Family'))  &
         (movies_df['content_rating']=='R') &
         (movies_df['duration'].between(120,150)) &
         (movies_df['star_rating']>= 8)]
# Out:
#      star_rating                               title content_rating   genre  \
# 20           8.7                          The Matrix              R  Action
# 45           8.5          Terminator 2: Judgment Day              R  Action
# 75           8.4                              Aliens              R  Action
# 138          8.3                            Die Hard              R  Action
# 152          8.2                      V for Vendetta              R  Action
# 163          8.2                                Rush              R  Action
# 173          8.2  Tae Guk Gi: The Brotherhood of War              R  Action
# 194          8.1        Kingsman: The Secret Service              R  Action
# 268          8.1                          The Raid 2              R  Action
# 296          8.1                      The Wild Bunch              R  Action
# 354          8.0                   Kill Bill: Vol. 2              R  Action
# ...

# %%
movies_df['genre'].unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movies_df[(movies_df['genre']=='Crime')|
         (movies_df['genre']=='Animation')|
         (movies_df['genre']=='Horror')|
         (movies_df['genre']=='Biography')]
# Out:
#      star_rating                     title content_rating      genre  \
# 0            9.3  The Shawshank Redemption              R      Crime
# 1            9.2             The Godfather              R      Crime
# 2            9.1    The Godfather: Part II              R      Crime
# 4            8.9              Pulp Fiction              R      Crime
# 8            8.9          Schindler's List              R  Biography
# ..           ...                       ...            ...        ...
# 964          7.4                   Lincoln          PG-13  Biography
# 966          7.4        The Simpsons Movie          PG-13  Animation
# 969          7.4       Law Abiding Citizen              R      Crime
# 977          7.4               Poltergeist             PG     Horror
# 978          7.4               Wall Street              R      Crime
#
#      duration                                        actors_list
# 0         142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# ...

# %%
movies_df[(movies_df['genre']=='Crime')|
         (movies_df['genre']=='Animation')|
         (movies_df['genre']=='Horror')|
         (movies_df['genre']=='Biography')]['genre'].value_counts()
# Out:
# Crime        124
# Biography     77
# Animation     62
# Horror        29
# Name: genre, dtype: int64

# %%
genre_list  = ['Crime','Horror','Biography','Animation']

movies_df[movies_df['genre'].isin(genre_list)]
# Out:
#      star_rating                     title content_rating      genre  \
# 0            9.3  The Shawshank Redemption              R      Crime
# 1            9.2             The Godfather              R      Crime
# 2            9.1    The Godfather: Part II              R      Crime
# 4            8.9              Pulp Fiction              R      Crime
# 8            8.9          Schindler's List              R  Biography
# ..           ...                       ...            ...        ...
# 964          7.4                   Lincoln          PG-13  Biography
# 966          7.4        The Simpsons Movie          PG-13  Animation
# 969          7.4       Law Abiding Citizen              R      Crime
# 977          7.4               Poltergeist             PG     Horror
# 978          7.4               Wall Street              R      Crime
#
#      duration                                        actors_list
# 0         142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# ...

# %%
genre_list  = ['Crime','Horror','Biography','Animation']
movies_df[(movies_df['genre'].isin(genre_list)) &
         (movies_df['content_rating'].isin(('R','PG-13')))]
# Out:
#      star_rating                     title content_rating      genre  \
# 0            9.3  The Shawshank Redemption              R      Crime
# 1            9.2             The Godfather              R      Crime
# 2            9.1    The Godfather: Part II              R      Crime
# 4            8.9              Pulp Fiction              R      Crime
# 8            8.9          Schindler's List              R  Biography
# ..           ...                       ...            ...        ...
# 961          7.4                    Capote              R  Biography
# 964          7.4                   Lincoln          PG-13  Biography
# 966          7.4        The Simpsons Movie          PG-13  Animation
# 969          7.4       Law Abiding Citizen              R      Crime
# 978          7.4               Wall Street              R      Crime
#
#      duration                                        actors_list
# 0         142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# ...
